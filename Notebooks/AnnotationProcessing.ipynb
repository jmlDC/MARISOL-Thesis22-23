# %% [markdown]
# <a href="https://colab.research.google.com/github/jmlDC/MediaBias-Thesis22-23/blob/PostAnnotation/Notebooks/AnnotationProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # MOUNTING Gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dir_actual = "/content/drive/MyDrive/THESIS-MS/MediaBias-Thesis22-23/dataset/annotators raw CSV/Actual/"

# %% [markdown]
# ## finding diff

# %%
# https://kanoki.org/2022/08/01/pandas-compare-columns-in-two-dataframes/
def fdiff(df,k1,k2):
    df['diff']=np.where(df[k1]['Text']==df[k2]['Text'], True, False)
    for i, r in df.iterrows():
        if r['diff'].bool()==False:
            print(i)

# %% [markdown]
# # Reading excel

# %% [markdown]
# ## Group A

# %%
# https://saturncloud.io/blog/how-to-remove-space-from-columns-in-pandas-a-data-scientists-guide/#:~:text=Using%20the%20str.strip(),column%20names%20or%20column%20values.
a1 = pd.read_excel(f"{dir_actual}1A-groupA-annotation.xlsx", usecols=["Text","Annotate"])
a1.rename(columns = {'Annotate':'A1-Annotations'}, inplace = True)
a1['Text'] = a1['Text'].apply(lambda x: x.strip())
a1
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations
# 0     4. Fairness and Equality
# 1           12. Public Opinion
# 2                13. Political
# 3                13. Political
# 4         9. Health and Safety
# ...                        ...
# 4996                 15. Other
# 4997                 15. Other
# 4998                 15. Other
# 4999                 15. Other
# 5000        12. Public Opinion
#
# [5001 rows x 2 columns]

# %%
a2 = pd.read_excel(f"{dir_actual}2A-groupA-annotation.xlsx", usecols=["Text","Annotate"])
a2.rename(columns = {'Annotate':'A2-Annotations'}, inplace = True)
a2['Text'] = a2['Text'].apply(lambda x: x.strip())
a2
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A2-Annotations
# 0     4. Fairness and Equality
# 1           12. Public Opinion
# 2                13. Political
# 3                13. Political
# 4         9. Health and Safety
# ...                        ...
# 4996                 15. Other
# 4997                 15. Other
# 4998                 15. Other
# 4999                 15. Other
# 5000        12. Public Opinion
#
# [5001 rows x 2 columns]

# %%
a3 = pd.read_excel(f"{dir_actual}3A-groupA-annotation.xlsx", usecols=["Text","Annotate"])
a3.rename(columns = {'Annotate':'A3-Annotations'}, inplace = True)
a3['Text'] = a3['Text'].apply(lambda x: x.strip())
a3
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                            A3-Annotations
# 0                4. Fairness and Equality
# 1                      12. Public Opinion
# 2     7. Law and Order, Crime and Justice
# 3                             1. Economic
# 4                    9. Health and Safety
# ...                                   ...
# 4996                            15. Other
# 4997                            15. Other
# 4998                            15. Other
# 4999                            15. Other
# 5000                   12. Public Opinion
#
# [5001 rows x 2 columns]

# %%
# concated_a = pd.concat([a1,a2,a3], axis=1,keys = ['a1', 'a2',"a3"]) #[['Text',"A1-Annotations", "A2-Annotations", "A3-Annotations"]]
concated_a = pd.concat([a1,a2,a3], axis=1)
concated_a
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations  \
# 0     4. Fairness and Equality
# 1           12. Public Opinion
# 2                13. Political
# 3                13. Political
# 4         9. Health and Safety
# ...                        ...
# 4996                 15. Other
# 4997                 15. Other
# 4998                 15. Other
# 4999                 15. Other
# 5000        12. Public Opinion
#
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A2-Annotations  \
# 0     4. Fairness and Equality
# 1           12. Public Opinion
# 2                13. Political
# 3                13. Political
# 4         9. Health and Safety
# ...                        ...
# 4996                 15. Other
# 4997                 15. Other
# 4998                 15. Other
# 4999                 15. Other
# 5000        12. Public Opinion
#
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                            A3-Annotations
# 0                4. Fairness and Equality
# 1                      12. Public Opinion
# 2     7. Law and Order, Crime and Justice
# 3                             1. Economic
# 4                    9. Health and Safety
# ...                                   ...
# 4996                            15. Other
# 4997                            15. Other
# 4998                            15. Other
# 4999                            15. Other
# 5000                   12. Public Opinion
#
# [5001 rows x 6 columns]

# %%
concatenated_a = concated_a.T.drop_duplicates().T

# %%
concatenated_a
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations            A2-Annotations  \
# 0     4. Fairness and Equality  4. Fairness and Equality
# 1           12. Public Opinion        12. Public Opinion
# 2                13. Political             13. Political
# 3                13. Political             13. Political
# 4         9. Health and Safety      9. Health and Safety
# ...                        ...                       ...
# 4996                 15. Other                 15. Other
# 4997                 15. Other                 15. Other
# 4998                 15. Other                 15. Other
# 4999                 15. Other                 15. Other
# 5000        12. Public Opinion        12. Public Opinion
#
#                            A3-Annotations
# 0                4. Fairness and Equality
# 1                      12. Public Opinion
# 2     7. Law and Order, Crime and Justice
# 3                             1. Economic
# 4                    9. Health and Safety
# ...                                   ...
# 4996                            15. Other
# 4997                            15. Other
# 4998                            15. Other
# 4999                            15. Other
# 5000                   12. Public Opinion
#
# [5001 rows x 4 columns]

# %% [markdown]
# ## Group B

# %%
b1 = pd.read_excel(f"{dir_actual}1B-groupB-annotation.xlsx", usecols=["Text","Annotate"])
b1.rename(columns = {'Annotate':'B1-Annotations'}, inplace = True)
b1['Text'] = b1['Text'].apply(lambda x: x.strip())
b1
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...                                     ...
# 4996                    10. Quality of Life
# 4997                8. Security and Defense
# 4998                8. Security and Defense
# 4999                    10. Quality of Life
# 5000                    10. Quality of Life
#
# [5001 rows x 2 columns]

# %%
b2 = pd.read_excel(f"{dir_actual}2B-groupB-annotation.xlsx", usecols=["Text","Annotate"])
b2.rename(columns = {'Annotate':'B2-Annotations'}, inplace = True)
b2['Text'] = b2['Text'].apply(lambda x: x.strip())
b2
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B2-Annotations
# 0                  4. Fairness and Equality
# 1                               1. Economic
# 2                             13. Political
# 3                      9. Health and Safety
# 4                       10. Quality of Life
# ...                                     ...
# 4996                8. Security and Defense
# 4997  6. Policy Prescription and Evaluation
# 4998  6. Policy Prescription and Evaluation
# 4999                   9. Health and Safety
# 5000                   9. Health and Safety
#
# [5001 rows x 2 columns]

# %%
b3 = pd.read_excel(f"{dir_actual}3B-groupB-annotation.xlsx", usecols=["Text","Annotate"])
b3.rename(columns = {'Annotate':'B3-Annotations'}, inplace = True)
b3['Text'] = b3['Text'].apply(lambda x: x.strip())
b3
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                  B3-Annotations
# 0      4. Fairness and Equality
# 1     2. Capacity and Resources
# 2                 13. Political
# 3          9. Health and Safety
# 4           10. Quality of Life
# ...                         ...
# 4996        10. Quality of Life
# 4997    8. Security and Defense
# 4998    8. Security and Defense
# 4999       9. Health and Safety
# 5000       9. Health and Safety
#
# [5001 rows x 2 columns]

# %%
concated_b = pd.concat([b1,b2,b3], axis=1)
concated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...                                     ...
# 4996                    10. Quality of Life
# 4997                8. Security and Defense
# 4998                8. Security and Defense
# 4999                    10. Quality of Life
# 5000                    10. Quality of Life
#
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B2-Annotations  \
# 0                  4. Fairness and Equality
# 1                               1. Economic
# 2                             13. Political
# 3                      9. Health and Safety
# 4                       10. Quality of Life
# ...                                     ...
# 4996                8. Security and Defense
# 4997  6. Policy Prescription and Evaluation
# 4998  6. Policy Prescription and Evaluation
# 4999                   9. Health and Safety
# 5000                   9. Health and Safety
#
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                  B3-Annotations
# 0      4. Fairness and Equality
# 1     2. Capacity and Resources
# 2                 13. Political
# 3          9. Health and Safety
# 4           10. Quality of Life
# ...                         ...
# 4996        10. Quality of Life
# 4997    8. Security and Defense
# 4998    8. Security and Defense
# 4999       9. Health and Safety
# 5000       9. Health and Safety
#
# [5001 rows x 6 columns]

# %%
concated = pd.concat([b1,b2,b3], axis=1,keys = ['1', '2',"3"])
fdiff(concated,'1','2')

# %%
concated.iat[4602,0],concated.iat[4602,0]
# Out:
# ("Act of kindness': Recto explains need to certify as urgent bill extending estate tax amnesty period",
#  "Act of kindness': Recto explains need to certify as urgent bill extending estate tax amnesty period")

# %%
concatenated_b = concated_b.T.drop_duplicates().T

# %%
concatenated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...                                     ...
# 4996                    10. Quality of Life
# 4997                8. Security and Defense
# 4998                8. Security and Defense
# 4999                    10. Quality of Life
# 5000                    10. Quality of Life
#
#                              B2-Annotations             B3-Annotations
# 0                  4. Fairness and Equality   4. Fairness and Equality
# 1                               1. Economic  2. Capacity and Resources
# 2                             13. Political              13. Political
# 3                      9. Health and Safety       9. Health and Safety
# 4                       10. Quality of Life        10. Quality of Life
# ...                                     ...                        ...
# 4996                8. Security and Defense        10. Quality of Life
# 4997  6. Policy Prescription and Evaluation    8. Security and Defense
# 4998  6. Policy Prescription and Evaluation    8. Security and Defense
# 4999                   9. Health and Safety       9. Health and Safety
# 5000                   9. Health and Safety       9. Health and Safety
#
# [5001 rows x 4 columns]

# %% [markdown]
# ## Group C

# %%
c1 = pd.read_excel(f"{dir_actual}1C-groupC-annotation.xlsx", usecols=["Text","Annotate"])
c1.rename(columns = {'Annotate':'C1-Annotations'}, inplace = True)
c1['Text'] = c1['Text'].apply(lambda x: x.strip())
c1
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
# [5000 rows x 2 columns]

# %%
c2 = pd.read_excel(f"{dir_actual}2C-groupC-annotation.xlsx", usecols=["Text","Annotate"])
c2.rename(columns = {'Annotate':'C2-Annotations'}, inplace = True)
c2['Text'] = c2['Text'].apply(lambda x: x.strip())
c2
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C2-Annotations
# 0                   4. Fairness and Equality
# 1      6. Policy Prescription and Evaluation
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                        10. Quality of Life
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                             3. Morality
#
# [5000 rows x 2 columns]

# %%
c3 = pd.read_excel(f"{dir_actual}3C-groupC-annotation.xlsx", usecols=["Text","Annotate"])
c3.rename(columns = {'Annotate':'C3-Annotations'}, inplace = True)
c3['Text'] = c3['Text'].apply(lambda x: x.strip())
c3
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C3-Annotations
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
# [5000 rows x 2 columns]

# %%
concated = pd.concat([c1,c2,c3], axis=1,keys = ['1', '2',"3"])
fdiff(concated,'1','2')

# %%
concated_c = pd.concat([c1,c2,c3], axis=1)
concated_c
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations  \
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C2-Annotations  \
# 0                   4. Fairness and Equality
# 1      6. Policy Prescription and Evaluation
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                        10. Quality of Life
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                             3. Morality
#
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C3-Annotations
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
# [5000 rows x 6 columns]

# %%
concatenated_c = concated_c.T.drop_duplicates().T
concatenated_c
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations  \
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
#                               C2-Annotations  \
# 0                   4. Fairness and Equality
# 1      6. Policy Prescription and Evaluation
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                        10. Quality of Life
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                             3. Morality
#
#                               C3-Annotations
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
# [5000 rows x 4 columns]

# %% [markdown]
# # Majority Ruling

# %%
# https://stackoverflow.com/a/43990682
def getMajority(df, a,b,c):
    mostCommonVote=[]
    for row in df[[a,b,c]].values:
        votes, values = np.unique(row, return_counts=True)
        if np.all(values<=1):
                mostCommonVote.append(False)
        else:
            mostCommonVote.append( votes[np.argmax(values)] )

    df['Majority-Frame'] = mostCommonVote

# %%
getMajority(concatenated_c,"C1-Annotations", "C2-Annotations", "C3-Annotations")
concatenated_c
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations  \
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
#                               C2-Annotations  \
# 0                   4. Fairness and Equality
# 1      6. Policy Prescription and Evaluation
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                        10. Quality of Life
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                             3. Morality
#
#                               C3-Annotations  \
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
#                               Majority-Frame
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                                  15. Other
# ...                                      ...
# 4995  14. External Regulation and Reputation
# 4996  14. External Regulation and Reputation
# 4997  14. External Regulation and Reputation
# 4998  14. External Regulation and Reputation
# 4999                   11. Cultural Identity
#
# [5000 rows x 5 columns]

# %%
getMajority(concatenated_a,"A1-Annotations", "A2-Annotations", "A3-Annotations")
concatenated_a
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations            A2-Annotations  \
# 0     4. Fairness and Equality  4. Fairness and Equality
# 1           12. Public Opinion        12. Public Opinion
# 2                13. Political             13. Political
# 3                13. Political             13. Political
# 4         9. Health and Safety      9. Health and Safety
# ...                        ...                       ...
# 4996                 15. Other                 15. Other
# 4997                 15. Other                 15. Other
# 4998                 15. Other                 15. Other
# 4999                 15. Other                 15. Other
# 5000        12. Public Opinion        12. Public Opinion
#
#                            A3-Annotations            Majority-Frame
# 0                4. Fairness and Equality  4. Fairness and Equality
# 1                      12. Public Opinion        12. Public Opinion
# 2     7. Law and Order, Crime and Justice             13. Political
# 3                             1. Economic             13. Political
# 4                    9. Health and Safety      9. Health and Safety
# ...                                   ...                       ...
# 4996                            15. Other                 15. Other
# 4997                            15. Other                 15. Other
# 4998                            15. Other                 15. Other
# 4999                            15. Other                 15. Other
# 5000                   12. Public Opinion        12. Public Opinion
#
# [5001 rows x 5 columns]

# %%
getMajority(concatenated_b,"B1-Annotations", "B2-Annotations", "B3-Annotations")
concatenated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...                                     ...
# 4996                    10. Quality of Life
# 4997                8. Security and Defense
# 4998                8. Security and Defense
# 4999                    10. Quality of Life
# 5000                    10. Quality of Life
#
#                              B2-Annotations             B3-Annotations  \
# 0                  4. Fairness and Equality   4. Fairness and Equality
# 1                               1. Economic  2. Capacity and Resources
# 2                             13. Political              13. Political
# 3                      9. Health and Safety       9. Health and Safety
# 4                       10. Quality of Life        10. Quality of Life
# ...                                     ...                        ...
# 4996                8. Security and Defense        10. Quality of Life
# 4997  6. Policy Prescription and Evaluation    8. Security and Defense
# 4998  6. Policy Prescription and Evaluation    8. Security and Defense
# 4999                   9. Health and Safety       9. Health and Safety
# 5000                   9. Health and Safety       9. Health and Safety
#
#                 Majority-Frame
# 0     4. Fairness and Equality
# 1                        False
# 2                13. Political
# 3         9. Health and Safety
# 4          10. Quality of Life
# ...                        ...
# 4996       10. Quality of Life
# 4997   8. Security and Defense
# 4998   8. Security and Defense
# 4999      9. Health and Safety
# 5000      9. Health and Safety
#
# [5001 rows x 5 columns]

# %%
for x in range(3):
    concatenated_a.rename(columns = {f'A{x+1}-Annotations':f"Annotation-{x+1}"}, inplace = True)
    concatenated_b.rename(columns = {f'B{x+1}-Annotations':f"Annotation-{x+1}"}, inplace = True)
    concatenated_c.rename(columns = {f'C{x+1}-Annotations':f"Annotation-{x+1}"}, inplace = True)

# %%
concatenated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                                Annotation-1  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...                                     ...
# 4996                    10. Quality of Life
# 4997                8. Security and Defense
# 4998                8. Security and Defense
# 4999                    10. Quality of Life
# 5000                    10. Quality of Life
#
#                                Annotation-2               Annotation-3  \
# 0                  4. Fairness and Equality   4. Fairness and Equality
# 1                               1. Economic  2. Capacity and Resources
# 2                             13. Political              13. Political
# 3                      9. Health and Safety       9. Health and Safety
# 4                       10. Quality of Life        10. Quality of Life
# ...                                     ...                        ...
# 4996                8. Security and Defense        10. Quality of Life
# 4997  6. Policy Prescription and Evaluation    8. Security and Defense
# 4998  6. Policy Prescription and Evaluation    8. Security and Defense
# 4999                   9. Health and Safety       9. Health and Safety
# 5000                   9. Health and Safety       9. Health and Safety
#
#                 Majority-Frame
# 0     4. Fairness and Equality
# 1                        False
# 2                13. Political
# 3         9. Health and Safety
# 4          10. Quality of Life
# ...                        ...
# 4996       10. Quality of Life
# 4997   8. Security and Defense
# 4998   8. Security and Defense
# 4999      9. Health and Safety
# 5000      9. Health and Safety
#
# [5001 rows x 5 columns]

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html
all_df = pd.concat([concatenated_a,concatenated_b,concatenated_c], axis=0,ignore_index=True)
all_df
# Out:
#                                                     Text  \
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1      The number of Filipinos against changing the C...
# 2      Jinggoy Estrada calls ICC probers 'white monke...
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...
# 4      The Department of Health (DOH) on Thursday mon...
# ...                                                  ...
# 14997  PH diplomat tells China not to question PH-US ...
# 14998  Philippine Ambassador to the United States Jos...
# 14999  China enjoins Asian countries to uphold ‘strat...
# 15000  China wants countries in Asia to “uphold strat...
# 15001  Public told: ‘Remember, honor, emulate valor o...
#
#                                  Annotation-1  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                   11. Cultural Identity
#
#                                  Annotation-2  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                             3. Morality
#
#                                  Annotation-3  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2         7. Law and Order, Crime and Justice
# 3                                 1. Economic
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                   11. Cultural Identity
#
#                                Majority-Frame
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                   11. Cultural Identity
#
# [15002 rows x 5 columns]

# %%
# https://www.geeksforgeeks.org/how-to-count-occurrences-of-specific-value-in-pandas-column/
all_df['Majority-Frame'].value_counts()[False]
# Out:
# 2709

# %%
# https://saturncloud.io/blog/how-to-reset-index-in-pandas-dataframe-after-dropna/#:~:text=The%20reset_index()%20method%20in,the%20index%20of%20the%20dataframe.
# https://saturncloud.io/blog/how-to-delete-dataframe-rows-in-pandas-based-on-column-value/#:~:text=To%20delete%20rows%20from%20a%20DataFrame%20based%20on%20a%20specific,of%20row%20labels%20to%20delete.
agree_df = all_df.drop(all_df[all_df['Majority-Frame'] == False].index)[['Text','Majority-Frame']]
agree_df.reset_index(inplace=True, drop=True)
agree_df
# Out:
#                                                     Text  \
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1      The number of Filipinos against changing the C...
# 2      Jinggoy Estrada calls ICC probers 'white monke...
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...
# 4      The Department of Health (DOH) on Thursday mon...
# ...                                                  ...
# 12288  PH diplomat tells China not to question PH-US ...
# 12289  Philippine Ambassador to the United States Jos...
# 12290  China enjoins Asian countries to uphold ‘strat...
# 12291  China wants countries in Asia to “uphold strat...
# 12292  Public told: ‘Remember, honor, emulate valor o...
#
#                                Majority-Frame
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 12288  14. External Regulation and Reputation
# 12289  14. External Regulation and Reputation
# 12290  14. External Regulation and Reputation
# 12291  14. External Regulation and Reputation
# 12292                   11. Cultural Identity
#
# [12293 rows x 2 columns]

# %%
c=0
for index, row in all_df.iterrows():
    # print(row['Majority-Frame'])
    if row['Majority-Frame'] == False:
        # print(index)
        c+=1
print(c)
# Out:
# 2709

# %%
# agree_df.to_csv(f'{dir_actual}agreed-PHdataset.csv', index=False)

# %% [markdown]
# # Interrater

# %% [markdown]
# ### 1st Fleiss kappa

# %%
annotations = all_df[['Annotation-1','Annotation-2','Annotation-3']]
annotations
# Out:
#                                  Annotation-1  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                   11. Cultural Identity
#
#                                  Annotation-2  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                             3. Morality
#
#                                  Annotation-3
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2         7. Law and Order, Crime and Justice
# 3                                 1. Economic
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                   11. Cultural Identity
#
# [15002 rows x 3 columns]

# %%
annotes = [all_df['Annotation-1'].tolist(),all_df['Annotation-2'].tolist(),all_df['Annotation-3'].tolist()]

# %%
# https://stackoverflow.com/questions/56481245/inter-rater-reliability-calculation-for-multi-raters-data
from statsmodels.stats import inter_rater as irr

irr.aggregate_raters(annotes)
# Out:
# (array([[ 621, 1136,  239,  376, 2842, 1340, 1043, 1209,  217,  231,  215,
#          1052, 2213,  874, 1394],
#         [ 357, 1125,  170,  447, 2175, 1387,  573, 1129,  406,  152,  715,
#          2361, 2167,  785, 1053],
#         [ 659, 1287,  210,  283, 1628, 1452,  542, 1361,  555,  593,  754,
#          1138, 2051, 1185, 1304]]),
#  array(['1. Economic', '10. Quality of Life', '11. Cultural Identity',
#         '12. Public Opinion', '13. Political',
#         '14. External Regulation and Reputation', '15. Other',
#         '2. Capacity and Resources', '3. Morality',
#         '4. Fairness and Equality',
#         '5. Constitutionality and Jurisprudence',
#         '6. Policy Prescription and Evaluation',
#         '7. Law and Order, Crime and Justice', '8. Security and Defense',
#         '9. Health and Safety'], dtype='<U38'))

# %%
# https://www.statsmodels.org/dev/generated/statsmodels.stats.inter_rater.fleiss_kappa.html#statsmodels.stats.inter_rater.fleiss_kappa
dats, cats = irr.aggregate_raters(annotes)
irr.fleiss_kappa(dats, method='fleiss')
# Out:
# 0.004179133215715416

# %%
dats[0]
# Out:
# array([ 621, 1136,  239,  376, 2842, 1340, 1043, 1209,  217,  231,  215,
#        1052, 2213,  874, 1394])

# %%
giro = np.array(annotes).transpose()
giro
# Out:
# array([['4. Fairness and Equality', '4. Fairness and Equality',
#         '4. Fairness and Equality'],
#        ['12. Public Opinion', '12. Public Opinion', '12. Public Opinion'],
#        ['13. Political', '13. Political',
#         '7. Law and Order, Crime and Justice'],
#        ...,
#        ['14. External Regulation and Reputation',
#         '14. External Regulation and Reputation',
#         '14. External Regulation and Reputation'],
#        ['14. External Regulation and Reputation',
#         '14. External Regulation and Reputation',
#         '14. External Regulation and Reputation'],
#        ['11. Cultural Identity', '3. Morality', '11. Cultural Identity']],
#       dtype='<U38')

# %%
irr.fleiss_kappa(irr.aggregate_raters(giro)[0], method='fleiss')
# Out:
# 0.45945392266497254

# %%
dats, cats = irr.aggregate_raters(annotations)
irr.fleiss_kappa(dats, method='fleiss')
# Out:
# 0.45945392266497254

# %% [markdown]
# ### 2nd Fleiss kappa

# %%
# https://medium.com/@nick.acosta/an-introduction-to-fleiss-kappa-36d3a9e7d606
def fleiss_kappa(lists, classes):
    n = len(lists)
    N = len(lists[0])
    k = len(classes)

    nij = []
    for i in range(N):
        nij.append([0]*k)


    for i in range(len(lists)):
        for j in range(len(lists[i])):
            nij[j][classes.index(lists[i][j])] += 1

    P = []
    for i in nij:
        P.append(1/(n*(n-1))*(sum([j*j for j in i])-n))

    return (((sum(P)/N)-(sum([y*y for y in [x/(N*n) for x in[sum(i) for i in zip(*nij)]]])))/(1-sum([y*y for y in [x/(N*n) for x in[sum(i) for i in zip(*nij)]]]))+1)/2

# %%
classes = ['-', 'o', '+'] # negative, neutral, positive

rater1 = ['+', '+', '+', '+', 'o', '+', 'o', '-', '+', 'o']
rater2 = ['+', '+', 'o', 'o', 'o', '+', 'o', 'o', '+', 'o']
rater3 = ['+', '+', '+', '+', 'o', '+', 'o', '-', '+', '+']

rate = [rater1, rater2, rater3]

print(fleiss_kappa(rate, classes))
# Out:
# 0.7530864197530864

# %%
A,B,C = all_df['Annotation-1'].tolist(),all_df['Annotation-2'].tolist(),all_df['Annotation-3'].tolist()

# %%
listahan = [A,B,C]
listahan
# Out:
# [['4. Fairness and Equality',
#   '12. Public Opinion',
#   '13. Political',
#   '13. Political',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '12. Public Opinion',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '4. Fairness and Equality',
#   '13. Political',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '12. Public Opinion',
#   '5. Constitutionality and Jurisprudence',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '13. Political',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '4. Fairness and Equality',
#   '13. Political',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '13. Political',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '13. Political',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '13. Political',
#   '4. Fairness and Equality',
#   '8. Security and Defense',
#   '3. Morality',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '14. External Regulation and Reputation',
#   '12. Public Opinion',
#   '13. Political',
#   '13. Political',
#   '3. Morality',
#   '10. Quality of Life',
#   '13. Political',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '11. Cultural Identity',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '13. Political',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '3. Morality',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '2. Capacity and Resources',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '15. Other',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '13. Political',
#   '2. Capacity and Resources',
#   '13. Political',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '12. Public Opinion',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '12. Public Opinion',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '13. Political',
#   '13. Political',
#   '15. Other',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '1. Economic',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '10. Quality of Life',
#   '15. Other',
#   '2. Capacity and Resources',
#   '15. Other',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '13. Political',
#   '3. Morality',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '10. Quality of Life',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '2. Capacity and Resources',
#   '4. Fairness and Equality',
#   '12. Public Opinion',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '12. Public Opinion',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '15. Other',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '12. Public Opinion',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '13. Political',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '13. Political',
#   '12. Public Opinion',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '4. Fairness and Equality',
#   '13. Political',
#   '1. Economic',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '13. Political',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '4. Fairness and Equality',
#   '13. Political',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '13. Political',
#   '15. Other',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '15. Other',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '15. Other',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '11. Cultural Identity',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '15. Other',
#   '2. Capacity and Resources',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '13. Political',
#   '13. Political',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '15. Other',
#   '2. Capacity and Resources',
#   '13. Political',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '13. Political',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '12. Public Opinion',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '12. Public Opinion',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '4. Fairness and Equality',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '15. Other',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '12. Public Opinion',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '10. Quality of Life',
#   '12. Public Opinion',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '2. Capacity and Resources',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '13. Political',
#   '13. Political',
#   '13. Political',
#   '11. Cultural Identity',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '13. Political',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '13. Political',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '15. Other',
#   '13. Political',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '9. Health and Safety',
#   '13. Political',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '12. Public Opinion',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '1. Economic',
#   '15. Other',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '13. Political',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '13. Political',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '4. Fairness and Equality',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '2. Capacity and Resources',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '13. Political',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '11. Cultural Identity',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '8. Security and Defense',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '11. Cultural Identity',
#   '8. Security and Defense',
#   '1. Economic',
#   '15. Other',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '1. Economic',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '1. Economic',
#   '15. Other',
#   '11. Cultural Identity',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '12. Public Opinion',
#   '8. Security and Defense',
#   '4. Fairness and Equality',
#   '11. Cultural Identity',
#   '1. Economic',
#   '9. Health and Safety',
#   '13. Political',
#   '13. Political',
#   '13. Political',
#   '15. Other',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '12. Public Opinion',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '13. Political',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '1. Economic',
#   '10. Quality of Life',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '1. Economic',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '15. Other',
#   '10. Quality of Life',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '11. Cultural Identity',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '8. Security and Defense',
#   '1. Economic',
#   '1. Economic',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '4. Fairness and Equality',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '9. Health and Safety',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '2. Capacity and Resources',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '13. Political',
#   '10. Quality of Life',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '1. Economic',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '10. Quality of Life',
#   '1. Economic',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '15. Other',
#   '1. Economic',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '13. Political',
#   '13. Political',
#   '1. Economic',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '15. Other',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '15. Other',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '1. Economic',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '12. Public Opinion',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '13. Political',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '3. Morality',
#   '9. Health and Safety',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '4. Fairness and Equality',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '15. Other',
#   ...],
#  ['4. Fairness and Equality',
#   '12. Public Opinion',
#   '13. Political',
#   '13. Political',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '12. Public Opinion',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '4. Fairness and Equality',
#   '15. Other',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '15. Other',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '15. Other',
#   '5. Constitutionality and Jurisprudence',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '4. Fairness and Equality',
#   '13. Political',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '13. Political',
#   '4. Fairness and Equality',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '4. Fairness and Equality',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '13. Political',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '1. Economic',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '2. Capacity and Resources',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '4. Fairness and Equality',
#   '6. Policy Prescription and Evaluation',
#   '3. Morality',
#   '10. Quality of Life',
#   '13. Political',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '12. Public Opinion',
#   '11. Cultural Identity',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '13. Political',
#   '1. Economic',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '3. Morality',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '1. Economic',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '15. Other',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '5. Constitutionality and Jurisprudence',
#   '8. Security and Defense',
#   '5. Constitutionality and Jurisprudence',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '13. Political',
#   '4. Fairness and Equality',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '12. Public Opinion',
#   '9. Health and Safety',
#   '13. Political',
#   '15. Other',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '3. Morality',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '8. Security and Defense',
#   '5. Constitutionality and Jurisprudence',
#   '15. Other',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '4. Fairness and Equality',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '2. Capacity and Resources',
#   '15. Other',
#   '13. Political',
#   '15. Other',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '4. Fairness and Equality',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '8. Security and Defense',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '11. Cultural Identity',
#   '1. Economic',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '8. Security and Defense',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '6. Policy Prescription and Evaluation',
#   '4. Fairness and Equality',
#   '12. Public Opinion',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '8. Security and Defense',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '11. Cultural Identity',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '1. Economic',
#   '9. Health and Safety',
#   '15. Other',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '12. Public Opinion',
#   '6. Policy Prescription and Evaluation',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '13. Political',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '8. Security and Defense',
#   '4. Fairness and Equality',
#   '13. Political',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '1. Economic',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '6. Policy Prescription and Evaluation',
#   '8. Security and Defense',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '15. Other',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '1. Economic',
#   '15. Other',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '1. Economic',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '15. Other',
#   '2. Capacity and Resources',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '13. Political',
#   '13. Political',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '15. Other',
#   '8. Security and Defense',
#   '13. Political',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '13. Political',
#   '9. Health and Safety',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '15. Other',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '13. Political',
#   '15. Other',
#   '13. Political',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '12. Public Opinion',
#   '13. Political',
# ...
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '4. Fairness and Equality',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '13. Political',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '4. Fairness and Equality',
#   '6. Policy Prescription and Evaluation',
#   '4. Fairness and Equality',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '4. Fairness and Equality',
#   '8. Security and Defense',
#   '4. Fairness and Equality',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '1. Economic',
#   '15. Other',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '1. Economic',
#   '8. Security and Defense',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '8. Security and Defense',
#   '10. Quality of Life',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '10. Quality of Life',
#   '1. Economic',
#   '2. Capacity and Resources',
#   '4. Fairness and Equality',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '4. Fairness and Equality',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '8. Security and Defense',
#   '10. Quality of Life',
#   '15. Other',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '13. Political',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '9. Health and Safety',
#   '13. Political',
#   '13. Political',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '13. Political',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '4. Fairness and Equality',
#   '3. Morality',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '13. Political',
#   '15. Other',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '1. Economic',
#   '14. External Regulation and Reputation',
#   '1. Economic',
#   '1. Economic',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '4. Fairness and Equality',
#   '10. Quality of Life',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '2. Capacity and Resources',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '8. Security and Defense',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '5. Constitutionality and Jurisprudence',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '1. Economic',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '12. Public Opinion',
#   '6. Policy Prescription and Evaluation',
#   '4. Fairness and Equality',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '2. Capacity and Resources',
#   '13. Political',
#   '10. Quality of Life',
#   '4. Fairness and Equality',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '9. Health and Safety',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '7. Law and Order, Crime and Justice',
#   '1. Economic',
#   '1. Economic',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '1. Economic',
#   '4. Fairness and Equality',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '13. Political',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '4. Fairness and Equality',
#   '14. External Regulation and Reputation',
#   '1. Economic',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '4. Fairness and Equality',
#   '8. Security and Defense',
#   '14. External Regulation and Reputation',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '9. Health and Safety',
#   '1. Economic',
#   '1. Economic',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '7. Law and Order, Crime and Justice',
#   '2. Capacity and Resources',
#   '1. Economic',
#   '4. Fairness and Equality',
#   '14. External Regulation and Reputation',
#   '4. Fairness and Equality',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
#   '13. Political',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '15. Other',
#   '8. Security and Defense',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '6. Policy Prescription and Evaluation',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '4. Fairness and Equality',
#   '9. Health and Safety',
#   '12. Public Opinion',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '10. Quality of Life',
#   '13. Political',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '13. Political',
#   '4. Fairness and Equality',
#   '13. Political',
#   '1. Economic',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '6. Policy Prescription and Evaluation',
#   '1. Economic',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '3. Morality',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '13. Political',
#   '9. Health and Safety',
#   '5. Constitutionality and Jurisprudence',
#   '6. Policy Prescription and Evaluation',
#   '9. Health and Safety',
#   '15. Other',
#   '7. Law and Order, Crime and Justice',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '7. Law and Order, Crime and Justice',
#   '5. Constitutionality and Jurisprudence',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '7. Law and Order, Crime and Justice',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '9. Health and Safety',
#   '9. Health and Safety',
#   '13. Political',
#   ...]]

# %%
classesframes = cats.tolist()
classesframes
# Out:
# ['1. Economic',
#  '10. Quality of Life',
#  '11. Cultural Identity',
#  '12. Public Opinion',
#  '13. Political',
#  '14. External Regulation and Reputation',
#  '15. Other',
#  '2. Capacity and Resources',
#  '3. Morality',
#  '4. Fairness and Equality',
#  '5. Constitutionality and Jurisprudence',
#  '6. Policy Prescription and Evaluation',
#  '7. Law and Order, Crime and Justice',
#  '8. Security and Defense',
#  '9. Health and Safety']

# %%
fleiss_kappa(listahan, classesframes)
# Out:
# 0.7297269613324522

# %% [markdown]
# ### 3rd Fleiss kappa

# %%
ratings = [(1, 'yes')] * 10 + [(1, 'no')] * 0  + \
[(2, 'yes')] * 8  + [(2, 'no')] * 2  + \
[(3, 'yes')] * 9  + [(3, 'no')] * 1  + \
[(4, 'yes')] * 0  + [(4, 'no')] * 10 + \
[(5, 'yes')] * 7  + [(5, 'no')] * 3

ratings
# Out:
# [(1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (1, 'yes'),
#  (2, 'yes'),
#  (2, 'yes'),
#  (2, 'yes'),
#  (2, 'yes'),
#  (2, 'yes'),
#  (2, 'yes'),
#  (2, 'yes'),
#  (2, 'yes'),
#  (2, 'no'),
#  (2, 'no'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'yes'),
#  (3, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (4, 'no'),
#  (5, 'yes'),
#  (5, 'yes'),
#  (5, 'yes'),
#  (5, 'yes'),
#  (5, 'yes'),
#  (5, 'yes'),
#  (5, 'yes'),
#  (5, 'no'),
#  (5, 'no'),
#  (5, 'no')]

# %%
# https://github.com/amirziai/learning/blob/master/statistics/Inter-rater%20agreement%20kappas.ipynb
# Adapted from https://gist.github.com/ShinNoNoir/4749548
def fleiss_kappa_2(ratings, n):
    '''
    Computes the Fleiss' kappa measure for assessing the reliability of
    agreement between a fixed number n of raters when assigning categorical
    ratings to a number of items.

    Args:
        ratings: a list of (item, category)-ratings
        n: number of rows raters annotated
    Returns:
        the Fleiss' kappa score

    See also:
        http://en.wikipedia.org/wiki/Fleiss'_kappa
    '''
    items = set()
    categories = set()
    n_ij = {}

    for i, c in ratings:
        items.add(i)
        categories.add(c)
        n_ij[(i,c)] = n_ij.get((i,c), 0) + 1

    N = len(items)

    p_j = dict(((c, sum(n_ij.get((i, c), 0) for i in items) / (1.0 * n * N)) for c in categories))
    P_i = dict(((i, (sum(n_ij.get((i, c), 0) ** 2 for c in categories) - n) / (n * (n - 1.0))) for i in items))

    P_bar = sum(P_i.values()) / (1.0 * N)
    P_e_bar = sum(value ** 2 for value in p_j.values())

    kappa = (P_bar - P_e_bar) / (1 - P_e_bar)

    return kappa

# %%
frames = []
for n in range(3):
    n = n+1
    additions = 0
    for x in classesframes:
        cnt = all_df[f'Annotation-{n}'].value_counts()[x]
        print(n,x, cnt)
        frames +=[(n,x)]*cnt
        additions += cnt
    print(n, additions)
# Out:
# 1 1. Economic 621
# 1 10. Quality of Life 1136
# 1 11. Cultural Identity 239
# 1 12. Public Opinion 376
# 1 13. Political 2842
# 1 14. External Regulation and Reputation 1340
# 1 15. Other 1043
# 1 2. Capacity and Resources 1209
# 1 3. Morality 217
# 1 4. Fairness and Equality 231
# 1 5. Constitutionality and Jurisprudence 215
# 1 6. Policy Prescription and Evaluation 1052
# 1 7. Law and Order, Crime and Justice 2213
# 1 8. Security and Defense 874
# 1 9. Health and Safety 1394
# 1 15002
# 2 1. Economic 357
# 2 10. Quality of Life 1125
# 2 11. Cultural Identity 170
# 2 12. Public Opinion 447
# 2 13. Political 2175
# 2 14. External Regulation and Reputation 1387
# 2 15. Other 573
# 2 2. Capacity and Resources 1129
# 2 3. Morality 406
# 2 4. Fairness and Equality 152
# 2 5. Constitutionality and Jurisprudence 715
# 2 6. Policy Prescription and Evaluation 2361
# 2 7. Law and Order, Crime and Justice 2167
# 2 8. Security and Defense 785
# 2 9. Health and Safety 1053
# 2 15002
# 3 1. Economic 659
# 3 10. Quality of Life 1287
# 3 11. Cultural Identity 210
# 3 12. Public Opinion 283
# 3 13. Political 1628
# 3 14. External Regulation and Reputation 1452
# 3 15. Other 542
# 3 2. Capacity and Resources 1361
# 3 3. Morality 555
# 3 4. Fairness and Equality 593
# 3 5. Constitutionality and Jurisprudence 754
# 3 6. Policy Prescription and Evaluation 1138
# 3 7. Law and Order, Crime and Justice 2051
# 3 8. Security and Defense 1185
# 3 9. Health and Safety 1304
# 3 15002

# %%
len(frames)
# Out:
# 45006

# %%
fleiss_kappa_2(ratings, 10)
# Out:
# 0.5302287581699346

# %%
fleiss_kappa_2(frames, 15002)
# Out:
# 0.004179133215715401
