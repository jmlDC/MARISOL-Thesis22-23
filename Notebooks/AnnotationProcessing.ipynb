# %% [markdown]
# <a href="https://colab.research.google.com/github/jmlDC/MediaBias-Thesis22-23/blob/PostAnnotation/Notebooks/AnnotationProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # MOUNTING Gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir_actual = "/content/drive/MyDrive/THESIS-MS/MediaBias-Thesis22-23/dataset/annotators raw CSV/Actual/"

# %%
dir  = "/content/drive/MyDrive/THESIS-MS/MediaBias-Thesis22-23/"

# %% [markdown]
# ## finding diff

# %%
# https://kanoki.org/2022/08/01/pandas-compare-columns-in-two-dataframes/
def fdiff(df,k1,k2):
    df['diff']=np.where(df[k1]['Text']==df[k2]['Text'], True, False)
    for i, r in df.iterrows():
        if r['diff'].bool()==False:
            print(i)

# %% [markdown]
# # Reading excel

# %% [markdown]
# ## Group A

# %%
# https://saturncloud.io/blog/how-to-remove-space-from-columns-in-pandas-a-data-scientists-guide/#:~:text=Using%20the%20str.strip(),column%20names%20or%20column%20values.
a1 = pd.read_excel(f"{dir_actual}1A-groupA-annotation.xlsx", usecols=["Text","Annotate"])
a1.rename(columns = {'Annotate':'A1-Annotations'}, inplace = True)
a1['Text'] = a1['Text'].apply(lambda x: x.strip())
a1
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations
# 0     4. Fairness and Equality
# 1           12. Public Opinion
# 2                13. Political
# 3                13. Political
# 4         9. Health and Safety
# ...                        ...
# 4996                 15. Other
# 4997                 15. Other
# ...

# %%
a2 = pd.read_excel(f"{dir_actual}2A-groupA-annotation.xlsx", usecols=["Text","Annotate"])
a2.rename(columns = {'Annotate':'A2-Annotations'}, inplace = True)
a2['Text'] = a2['Text'].apply(lambda x: x.strip())
a2
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A2-Annotations
# 0     4. Fairness and Equality
# 1           12. Public Opinion
# 2                13. Political
# 3                13. Political
# 4         9. Health and Safety
# ...                        ...
# 4996                 15. Other
# 4997                 15. Other
# ...

# %%
a3 = pd.read_excel(f"{dir_actual}3A-groupA-annotation.xlsx", usecols=["Text","Annotate"])
a3.rename(columns = {'Annotate':'A3-Annotations'}, inplace = True)
a3['Text'] = a3['Text'].apply(lambda x: x.strip())
a3
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                            A3-Annotations
# 0                4. Fairness and Equality
# 1                      12. Public Opinion
# 2     7. Law and Order, Crime and Justice
# 3                             1. Economic
# 4                    9. Health and Safety
# ...

# %%
# concated_a = pd.concat([a1,a2,a3], axis=1,keys = ['a1', 'a2',"a3"]) #[['Text',"A1-Annotations", "A2-Annotations", "A3-Annotations"]]
concated_a = pd.concat([a1,a2,a3], axis=1)
concated_a
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations  \
# 0     4. Fairness and Equality
# 1           12. Public Opinion
# 2                13. Political
# 3                13. Political
# 4         9. Health and Safety
# ...                        ...
# 4996                 15. Other
# ...

# %%
concatenated_a = concated_a.T.drop_duplicates().T

# %%
concatenated_a
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations            A2-Annotations  \
# 0     4. Fairness and Equality  4. Fairness and Equality
# 1           12. Public Opinion        12. Public Opinion
# 2                13. Political             13. Political
# 3                13. Political             13. Political
# ...

# %% [markdown]
# ## Group B

# %%
b1 = pd.read_excel(f"{dir_actual}1B-groupB-annotation.xlsx", usecols=["Text","Annotate"])
b1.rename(columns = {'Annotate':'B1-Annotations'}, inplace = True)
b1['Text'] = b1['Text'].apply(lambda x: x.strip())
b1
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...

# %%
b2 = pd.read_excel(f"{dir_actual}2B-groupB-annotation.xlsx", usecols=["Text","Annotate"])
b2.rename(columns = {'Annotate':'B2-Annotations'}, inplace = True)
b2['Text'] = b2['Text'].apply(lambda x: x.strip())
b2
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B2-Annotations
# 0                  4. Fairness and Equality
# 1                               1. Economic
# 2                             13. Political
# 3                      9. Health and Safety
# 4                       10. Quality of Life
# ...

# %%
b3 = pd.read_excel(f"{dir_actual}3B-groupB-annotation.xlsx", usecols=["Text","Annotate"])
b3.rename(columns = {'Annotate':'B3-Annotations'}, inplace = True)
b3['Text'] = b3['Text'].apply(lambda x: x.strip())
b3
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                  B3-Annotations
# 0      4. Fairness and Equality
# 1     2. Capacity and Resources
# 2                 13. Political
# 3          9. Health and Safety
# 4           10. Quality of Life
# ...                         ...
# 4996        10. Quality of Life
# ...

# %%
concated_b = pd.concat([b1,b2,b3], axis=1)
concated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...

# %%
concated = pd.concat([b1,b2,b3], axis=1,keys = ['1', '2',"3"])
fdiff(concated,'1','2')

# %%
concated.iat[4602,0],concated.iat[4602,0]
# Out:
# ("Act of kindness': Recto explains need to certify as urgent bill extending estate tax amnesty period",
#  "Act of kindness': Recto explains need to certify as urgent bill extending estate tax amnesty period")

# %%
concatenated_b = concated_b.T.drop_duplicates().T

# %%
concatenated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...

# %% [markdown]
# ## Group C

# %%
c1 = pd.read_excel(f"{dir_actual}1C-groupC-annotation.xlsx", usecols=["Text","Annotate"])
c1.rename(columns = {'Annotate':'C1-Annotations'}, inplace = True)
c1['Text'] = c1['Text'].apply(lambda x: x.strip())
c1
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...

# %%
c2 = pd.read_excel(f"{dir_actual}2C-groupC-annotation.xlsx", usecols=["Text","Annotate"])
c2.rename(columns = {'Annotate':'C2-Annotations'}, inplace = True)
c2['Text'] = c2['Text'].apply(lambda x: x.strip())
c2
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C2-Annotations
# 0                   4. Fairness and Equality
# 1      6. Policy Prescription and Evaluation
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                        10. Quality of Life
# ...

# %%
c3 = pd.read_excel(f"{dir_actual}3C-groupC-annotation.xlsx", usecols=["Text","Annotate"])
c3.rename(columns = {'Annotate':'C3-Annotations'}, inplace = True)
c3['Text'] = c3['Text'].apply(lambda x: x.strip())
c3
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C3-Annotations
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2      6. Policy Prescription and Evaluation
# 3                                  15. Other
# 4                                  15. Other
# ...

# %%
concated = pd.concat([c1,c2,c3], axis=1,keys = ['1', '2',"3"])
fdiff(concated,'1','2')

# %%
concated_c = pd.concat([c1,c2,c3], axis=1)
concated_c
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations  \
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...

# %%
concatenated_c = concated_c.T.drop_duplicates().T
concatenated_c
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations  \
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...

# %% [markdown]
# # Majority Ruling

# %%
# https://stackoverflow.com/a/43990682
def getMajority(df, a,b,c):
    mostCommonVote=[]
    for row in df[[a,b,c]].values:
        votes, values = np.unique(row, return_counts=True)
        if np.all(values<=1):
                mostCommonVote.append(False)
        else:
            mostCommonVote.append( votes[np.argmax(values)] )

    df['Majority-Frame'] = mostCommonVote

# %%
getMajority(concatenated_c,"C1-Annotations", "C2-Annotations", "C3-Annotations")
concatenated_c
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Bill on developing sustainable communities get...
# 2     Senate ratifies RCEP, eyes creation of oversig...
# 3     Senior citizen in Davao del Sur claims P35-M l...
# 4          ‘Amihan’ continues to bring rains over Luzon
# ...                                                 ...
# 4995  PH diplomat tells China not to question PH-US ...
# 4996  Philippine Ambassador to the United States Jos...
# 4997  China enjoins Asian countries to uphold ‘strat...
# 4998  China wants countries in Asia to “uphold strat...
# 4999  Public told: ‘Remember, honor, emulate valor o...
#
#                               C1-Annotations  \
# 0                   4. Fairness and Equality
# 1                        10. Quality of Life
# 2     14. External Regulation and Reputation
# 3                                  15. Other
# 4                                  15. Other
# ...

# %%
getMajority(concatenated_a,"A1-Annotations", "A2-Annotations", "A3-Annotations")
concatenated_a
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     The number of Filipinos against changing the C...
# 2     Jinggoy Estrada calls ICC probers 'white monke...
# 3     President Ferdinand “Bongbong” Marcos Jr. has ...
# 4     The Department of Health (DOH) on Thursday mon...
# ...                                                 ...
# 4996      Grand, Mega lotto jackpots still up for grabs
# 4997  No one hit the jackpot prizes for Grand Lotto ...
# 4998  PRC announces results for April 2023 Electroni...
# 4999  The Professional Regulation Commission (PRC) a...
# 5000      Tulfo most trusted, approved senator — survey
#
#                 A1-Annotations            A2-Annotations  \
# 0     4. Fairness and Equality  4. Fairness and Equality
# 1           12. Public Opinion        12. Public Opinion
# 2                13. Political             13. Political
# 3                13. Political             13. Political
# ...

# %%
getMajority(concatenated_b,"B1-Annotations", "B2-Annotations", "B3-Annotations")
concatenated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                              B1-Annotations  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...

# %%
for x in range(3):
    concatenated_a.rename(columns = {f'A{x+1}-Annotations':f"Annotation-{x+1}"}, inplace = True)
    concatenated_b.rename(columns = {f'B{x+1}-Annotations':f"Annotation-{x+1}"}, inplace = True)
    concatenated_c.rename(columns = {f'C{x+1}-Annotations':f"Annotation-{x+1}"}, inplace = True)

# %%
concatenated_b
# Out:
#                                                    Text  \
# 0     Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1     Ressa’s acquittal impacts investment climate p...
# 2     FULL TEXT: Vice president-elect Sara Duterte i...
# 3     Highlights of WHO chief’s visit to Manila, a s...
# 4     MANILA, Philippines – Due to the scheduled nat...
# ...                                                 ...
# 4996  The National Security Council (NSC)  “with gre...
# 4997  Tolentino: Include simulation of OFW evacuatio...
# 4998  Senator Francis "Tol" Tolentino on Monday, Apr...
# 4999  PH can learn from Japan’s drastic smoking rate...
# 5000  The Philippines – where 1 in 4 adults are smok...
#
#                                Annotation-1  \
# 0                  4. Fairness and Equality
# 1     6. Policy Prescription and Evaluation
# 2                             13. Political
# 3                      9. Health and Safety
# 4                 2. Capacity and Resources
# ...

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html
all_df = pd.concat([concatenated_a,concatenated_b,concatenated_c], axis=0,ignore_index=True)
all_df
# Out:
#                                                     Text  \
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1      The number of Filipinos against changing the C...
# 2      Jinggoy Estrada calls ICC probers 'white monke...
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...
# 4      The Department of Health (DOH) on Thursday mon...
# ...                                                  ...
# 14997  PH diplomat tells China not to question PH-US ...
# 14998  Philippine Ambassador to the United States Jos...
# 14999  China enjoins Asian countries to uphold ‘strat...
# 15000  China wants countries in Asia to “uphold strat...
# 15001  Public told: ‘Remember, honor, emulate valor o...
#
#                                  Annotation-1  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# ...

# %%
# all_df.to_csv(f'{dir_actual}allDF-Annotation.csv', index=False)

# %%
# https://www.geeksforgeeks.org/how-to-count-occurrences-of-specific-value-in-pandas-column/
all_df['Majority-Frame'].value_counts()[False]
# Out:
# 2709

# %%
# https://saturncloud.io/blog/how-to-reset-index-in-pandas-dataframe-after-dropna/#:~:text=The%20reset_index()%20method%20in,the%20index%20of%20the%20dataframe.
# https://saturncloud.io/blog/how-to-delete-dataframe-rows-in-pandas-based-on-column-value/#:~:text=To%20delete%20rows%20from%20a%20DataFrame%20based%20on%20a%20specific,of%20row%20labels%20to%20delete.
agree_df = all_df.drop(all_df[all_df['Majority-Frame'] == False].index)[['Text','Majority-Frame']]
agree_df.reset_index(inplace=True, drop=True)
agree_df
# Out:
#                                                     Text  \
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...
# 1      The number of Filipinos against changing the C...
# 2      Jinggoy Estrada calls ICC probers 'white monke...
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...
# 4      The Department of Health (DOH) on Thursday mon...
# ...                                                  ...
# 12288  PH diplomat tells China not to question PH-US ...
# 12289  Philippine Ambassador to the United States Jos...
# 12290  China enjoins Asian countries to uphold ‘strat...
# 12291  China wants countries in Asia to “uphold strat...
# 12292  Public told: ‘Remember, honor, emulate valor o...
#
#                                Majority-Frame
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# ...

# %%
c=0
for index, row in all_df.iterrows():
    # print(row['Majority-Frame'])
    if row['Majority-Frame'] == False:
        # print(index)
        c+=1
print(c)
# Out:
# 2709

# %% [markdown]
# ### exporting

# %%
# agree_df.to_csv(f'{dir_actual}agreed-PHdataset.csv', index=False)

# %%
# concatenated_c.to_csv(f'{dir_actual}grpC-Annotation.csv', index=False)
# concatenated_b.to_csv(f'{dir_actual}grpB-Annotation.csv', index=False)
# concatenated_a.to_csv(f'{dir_actual}grpA-Annotation.csv', index=False)

# %% [markdown]
# # Interrater

# %% [markdown]
# ### 1st Fleiss kappa

# %%
annotations = all_df[['Annotation-1','Annotation-2','Annotation-3']]
annotations
# Out:
#                                  Annotation-1  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# 14998  14. External Regulation and Reputation
# 14999  14. External Regulation and Reputation
# 15000  14. External Regulation and Reputation
# 15001                   11. Cultural Identity
#
#                                  Annotation-2  \
# 0                    4. Fairness and Equality
# 1                          12. Public Opinion
# 2                               13. Political
# 3                               13. Political
# 4                        9. Health and Safety
# ...                                       ...
# 14997  14. External Regulation and Reputation
# ...

# %% [markdown]
# Option A

# %%
annotes = [all_df['Annotation-1'].tolist(),all_df['Annotation-2'].tolist(),all_df['Annotation-3'].tolist()]

# %%
# https://stackoverflow.com/questions/56481245/inter-rater-reliability-calculation-for-multi-raters-data
from statsmodels.stats import inter_rater as irr

irr.aggregate_raters(annotes)
# Out:
# (array([[ 621, 1136,  239,  376, 2842, 1340, 1043, 1209,  217,  231,  215,
#          1052, 2213,  874, 1394],
#         [ 357, 1125,  170,  447, 2175, 1387,  573, 1129,  406,  152,  715,
#          2361, 2167,  785, 1053],
#         [ 659, 1287,  210,  283, 1628, 1452,  542, 1361,  555,  593,  754,
#          1138, 2051, 1185, 1304]]),
#  array(['1. Economic', '10. Quality of Life', '11. Cultural Identity',
#         '12. Public Opinion', '13. Political',
#         '14. External Regulation and Reputation', '15. Other',
#         '2. Capacity and Resources', '3. Morality',
#         '4. Fairness and Equality',
#         '5. Constitutionality and Jurisprudence',
#         '6. Policy Prescription and Evaluation',
#         '7. Law and Order, Crime and Justice', '8. Security and Defense',
#         '9. Health and Safety'], dtype='<U38'))

# %%
# https://www.statsmodels.org/dev/generated/statsmodels.stats.inter_rater.fleiss_kappa.html#statsmodels.stats.inter_rater.fleiss_kappa
dats, cats = irr.aggregate_raters(annotes)
irr.fleiss_kappa(dats, method='fleiss')
# Out:
# 0.004179133215715416

# %%
giro = np.array(annotes).transpose()
giro
# Out:
# array([['4. Fairness and Equality', '4. Fairness and Equality',
#         '4. Fairness and Equality'],
#        ['12. Public Opinion', '12. Public Opinion', '12. Public Opinion'],
#        ['13. Political', '13. Political',
#         '7. Law and Order, Crime and Justice'],
#        ...,
#        ['14. External Regulation and Reputation',
#         '14. External Regulation and Reputation',
#         '14. External Regulation and Reputation'],
#        ['14. External Regulation and Reputation',
#         '14. External Regulation and Reputation',
#         '14. External Regulation and Reputation'],
#        ['11. Cultural Identity', '3. Morality', '11. Cultural Identity']],
#       dtype='<U38')

# %%
irr.fleiss_kappa(irr.aggregate_raters(giro)[0], method='fleiss')
# Out:
# 0.45945392266497254

# %% [markdown]
# Option B

# %%
dats, cats = irr.aggregate_raters(annotations)
irr.fleiss_kappa(dats, method='fleiss')
# Out:
# 0.45945392266497254

# %% [markdown]
# ### 2nd Fleiss kappa

# %%
# https://medium.com/@nick.acosta/an-introduction-to-fleiss-kappa-36d3a9e7d606
def fleiss_kappa(lists, classes):
    n = len(lists)
    N = len(lists[0])
    k = len(classes)

    nij = []
    for i in range(N):
        nij.append([0]*k)


    for i in range(len(lists)):
        for j in range(len(lists[i])):
            nij[j][classes.index(lists[i][j])] += 1

    P = []
    for i in nij:
        P.append(1/(n*(n-1))*(sum([j*j for j in i])-n))

    return (((sum(P)/N)-(sum([y*y for y in [x/(N*n) for x in[sum(i) for i in zip(*nij)]]])))/(1-sum([y*y for y in [x/(N*n) for x in[sum(i) for i in zip(*nij)]]]))+1)/2

# %%
classes = ['-', 'o', '+'] # negative, neutral, positive

rater1 = ['+', '+', '+', '+', 'o', '+', 'o', '-', '+', 'o']
rater2 = ['+', '+', 'o', 'o', 'o', '+', 'o', 'o', '+', 'o']
rater3 = ['+', '+', '+', '+', 'o', '+', 'o', '-', '+', '+']

rate = [rater1, rater2, rater3]

print(fleiss_kappa(rate, classes))
# Out:
# 0.7530864197530864

# %%
A,B,C = all_df['Annotation-1'].tolist(),all_df['Annotation-2'].tolist(),all_df['Annotation-3'].tolist()

# %%
listahan = [A,B,C]
listahan
# Out:
# [['4. Fairness and Equality',
#   '12. Public Opinion',
#   '13. Political',
#   '13. Political',
#   '9. Health and Safety',
#   '6. Policy Prescription and Evaluation',
#   '14. External Regulation and Reputation',
#   '2. Capacity and Resources',
#   '2. Capacity and Resources',
#   '14. External Regulation and Reputation',
#   '14. External Regulation and Reputation',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '10. Quality of Life',
#   '2. Capacity and Resources',
#   '6. Policy Prescription and Evaluation',
#   '12. Public Opinion',
#   '2. Capacity and Resources',
#   '5. Constitutionality and Jurisprudence',
#   '6. Policy Prescription and Evaluation',
#   '2. Capacity and Resources',
#   '9. Health and Safety',
#   '7. Law and Order, Crime and Justice',
#   '8. Security and Defense',
#   '4. Fairness and Equality',
#   '13. Political',
#   '9. Health and Safety',
#   '13. Political',
#   '7. Law and Order, Crime and Justice',
# ...

# %%
classesframes = cats.tolist()
classesframes
# Out:
# ['1. Economic',
#  '10. Quality of Life',
#  '11. Cultural Identity',
#  '12. Public Opinion',
#  '13. Political',
#  '14. External Regulation and Reputation',
#  '15. Other',
#  '2. Capacity and Resources',
#  '3. Morality',
#  '4. Fairness and Equality',
#  '5. Constitutionality and Jurisprudence',
#  '6. Policy Prescription and Evaluation',
#  '7. Law and Order, Crime and Justice',
#  '8. Security and Defense',
#  '9. Health and Safety']

# %%
fleiss_kappa(listahan, classesframes)
# Out:
# 0.7297269613324522

# %% [markdown]
# # Preprocess Dataset

# %% [markdown]
# ## MFC

# %%
mfc = pd.read_csv(f'{dir}dataset/Extracted-News-May5-7/MFC_prepared.csv', usecols=["code_frames", "annotations"], header=0)
mfc.code_frames = mfc.code_frames.astype(int)

mfc.drop_duplicates(inplace=True)
mfc.rename(columns = {'annotations':'text'}, inplace = True)

label_dict = {}
for x in range(15):
    label_dict[x+1] = x

mfc['label'] = mfc.code_frames.replace(label_dict)
mfc
# Out:
#        code_frames                                               text  label
# 0               10  Immigrants without HOPE need help entering col...      9
# 1                5  But in the eyes of the law, he is an illegal i...      4
# 2               15            Reaction to Tancredo, Lamm as predicted     14
# 3               13  That, said the congressman, is what always hap...     12
# 4                1                                  $50,000 per entry      0
# ...            ...                                                ...    ...
# 46794           11                 Smoking is becoming a social taboo     10
# 46795            5   Nor does it aid lawyers seeking novel ways to...      4
# 46796           15                                   'Ashes to Ashes'     14
# 46797           15          SMOKE SCREEN IS SEEN BEHIND THE SMOKELESS     14
# 46798            1             CIGARETTE MAKERS AND THE PUBLIC HEALTH      0
#
# [45535 rows x 3 columns]

# %%
# mfc.to_csv(f'{dir}dataset/final/mfc.csv', index=False)

# %%
mfc_shuffled = mfc.sample(frac=1)
mfc_splits = np.array_split(mfc_shuffled, 2)

# %%
mfc_split_1, mfc_split_2 = mfc_splits

# %%
mfc_split_1
# Out:
#        code_frames                                               text  label
# 20405           13  Federal Agency to Begin a Survey On Use of Sem...     12
# 41210            9  SMOKING Feds studying need for cigar warning l...      8
# 23799            6  n a resolution calling for an indefinite morat...      5
# 46582            1  Prices continued to improve on North Carolina'...      0
# 16530            5             We should also revere Second Amendment      4
# ...            ...                                                ...    ...
# 43796            6           State's tobacco pre-emption law turns 10      5
# 9512             7  The question they never answer is why, even th...      6
# 38370            5  When the Supreme Court invalidated Virginia's ...      4
# 26170           13               HOUSE APPROVES TOUGH ANTI-CRIME BILL     12
# 25344            7   to allow bond for one of two cousins who face...      6
#
# [22768 rows x 3 columns]

# %%
mfc_split_2
# Out:
#        code_frames                                               text  label
# 40907           13  The wording was inserted by lawmakers at the i...     12
# 33656           11                    And like Vladimir and Estragon,     10
# 31069           13                  Gay nuptials bill on Romer's desk     12
# 6109            13   stepping into one of the most contentious top...     12
# 18227           11             Quilt museum takes aim at gun violence     10
# ...            ...                                                ...    ...
# 38068           13  "New York Republican leadership is much smarte...     12
# 2139            13               The Icebergs Ahead For the Democrats     12
# 27387            5                       2 courts review Wolfe's case      4
# 35859           11  Despite deep roots in New York, they will fly ...     10
# 21233           12                               N.R.A.'s New Ad Idea     11
#
# [22767 rows x 3 columns]

# %% [markdown]
# Train-test split 80-20 stratify label and random state 42

# %%
train_mfc, validation_mfc = train_test_split(mfc,
                                     test_size=0.2,
                                     random_state=42,
                                     stratify=mfc.label.values)

# %% [markdown]
# ## PH

# %%
ph = pd.read_csv(f'{dir_actual}agreed-PHdataset.csv')
ph.rename(columns = {'Text':'text', "Majority-Frame": 'code_frames'}, inplace = True)

# %%
code_frame_dict_1 = {'1. Economic': 1,
                   '2. Capacity and Resources':2,
                   '3. Morality':3,
                   '4. Fairness and Equality':4,
                   '5. Constitutionality and Jurisprudence':5,
                   '6. Policy Prescription and Evaluation':6,
                   '7. Law and Order, Crime and Justice':7,
                   '8. Security and Defense':8,
                   '9. Health and Safety':9,
                   '10. Quality of Life':10,
                   '11. Cultural Identity':11,
                   '12. Public Opinion':12,
                   '13. Political':13,
                   '14. External Regulation and Reputation':14,
                   '15. Other':15
 }

# %%
code_frame_dict = {}
for x in range(15):
    code_frame_dict[x+1] = x

# %%
ph['code_frames'] = ph.code_frames.replace(code_frame_dict_1)
ph
# Out:
#                                                     text  code_frames
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...            4
# 1      The number of Filipinos against changing the C...           12
# 2      Jinggoy Estrada calls ICC probers 'white monke...           13
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...           13
# 4      The Department of Health (DOH) on Thursday mon...            9
# ...                                                  ...          ...
# 12288  PH diplomat tells China not to question PH-US ...           14
# 12289  Philippine Ambassador to the United States Jos...           14
# 12290  China enjoins Asian countries to uphold ‘strat...           14
# 12291  China wants countries in Asia to “uphold strat...           14
# 12292  Public told: ‘Remember, honor, emulate valor o...           11
#
# [12293 rows x 2 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

sns.set(style="darkgrid")
ax = sns.countplot(x="code_frames",  data=ph, hue='code_frames', dodge=False)
ax.set(xlabel='code frames', ylabel='count of frame instances')


plt.legend(labels = ['1: Economic', '2: Capacity and Resources', '3: Morality', '4: Fairness and Equality', '5: Constitutionality and jurisprudence',
                     '6: Policy Prescription and Evaluation', '7: Law and Order, Crime and Justice', '8: Security and Defense', '9: Health and safety', '10: Quality of life',
                     '11: Cultural identity', '12: Public opinion', '13: Political', '14: External regulation and reputation', '15: Other'
                     ], loc='upper right', bbox_to_anchor=(1.75, 1))

plt.show()

# %%
ph['label'] = ph.code_frames.replace(code_frame_dict)
ph
# Out:
#                                                     text  code_frames  label
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...            4      3
# 1      The number of Filipinos against changing the C...           12     11
# 2      Jinggoy Estrada calls ICC probers 'white monke...           13     12
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...           13     12
# 4      The Department of Health (DOH) on Thursday mon...            9      8
# ...                                                  ...          ...    ...
# 12288  PH diplomat tells China not to question PH-US ...           14     13
# 12289  Philippine Ambassador to the United States Jos...           14     13
# 12290  China enjoins Asian countries to uphold ‘strat...           14     13
# 12291  China wants countries in Asia to “uphold strat...           14     13
# 12292  Public told: ‘Remember, honor, emulate valor o...           11     10
#
# [12293 rows x 3 columns]

# %%
# ph.to_csv(f'{dir}dataset/final/ph_dataset.csv', index=False)

# %%
# https://www.skytowner.com/explore/randomly_splitting_dataframe_into_multiple_dataframes_of_equal_size_in_pandas
ph_shuffled = ph.sample(frac=1)
ph_splits = np.array_split(ph_shuffled, 2)

# %%
ph_split_1, phsplit_2 = ph_splits

# %%
ph_split_1
# Out:
#                                                     text  code_frames  label
# 2025   Malaysia, US help Ph search for missing medeva...           14     13
# 7718   Spoon, 'tabo', seasoning: Clarita Carlos' trav...           15     14
# 4209   PNP 'quota system' to boost ICC case vs Dutert...            7      6
# 95     The Philippines, being the main security ally ...           14     13
# 8271   House leader dares US, China: Prove your affec...           14     13
# ...                                                  ...          ...    ...
# 5330   Vaccination not required when schools shift to...            9      8
# 11989  Senator Ronald ‘’Bato’’ dela Rosa is optimisti...            6      5
# 438    President Ferdinand "Bongbong" Marcos Jr. will...           14     13
# 4005   Maynilad announces water interruption in some ...           10      9
# 1465   Youth groups call for true freedom, end to rep...           12     11
#
# [6147 rows x 3 columns]

# %%
phsplit_2
# Out:
#                                                     text  code_frames  label
# 4864   PNP to roll out nationwide security dialogues ...            8      7
# 5260   Guevarra: ‘Best efforts’ to resolve Bloody Sun...            7      6
# 10221  MANILA – The Department of Energy (DOE) report...            2      1
# 3844   Bureau of Immigration (BI) Commissioner Norman...            7      6
# 10271  MANILA – The over 90 million official ballots ...           13     12
# ...                                                  ...          ...    ...
# 199    VP Sara: Lack of school facilities still basic...            2      1
# 10255  Centino thanks Japan's assistance to AFP moder...           14     13
# 7305   MANILA, Philippines – By requesting the Intern...            5      4
# 6436   2021 ‘deadliest’ year in PH history with over ...            9      8
# 9      Manalo, Galvez to lead PH delegation in dialog...           14     13
#
# [6146 rows x 3 columns]

# %% [markdown]
# Train-test split 80-20 stratify label and random state 42

# %%
train_ph, validation_ph = train_test_split(ph,
                                     test_size=0.2,
                                     random_state=42,
                                     stratify=ph.label.values)

# %% [markdown]
# ## Proportioning mfc and ph

# %%
combined_train = pd.concat([train_mfc,train_ph], axis=0, ignore_index=True)
combined_train
# Out:
#        code_frames                                               text  label
# 0               13                  Va. and Md. Reject Ban On Smoking     12
# 1                7  Ross Clayton Green, a 20-year-old resident of ...      6
# 2                7   In St. Louis, several area police chiefs said...      6
# 3                3    that it would be an honor to die for his crimes      2
# 4                5   is not entitled to immunity under Florida's "...      4
# ...            ...                                                ...    ...
# 46257            2  The oil spill in Oriental Mindoro, which alrea...      1
# 46258            2  The Philippine National Police (PNP) announced...      1
# 46259           13  ILOCOS NORTE, Philippines – Presidential candi...     12
# 46260            3  Anti-God': Bro Eddie wants to probe inclusion ...      2
# 46261           13  MANILA – Malacañang on Thursday announced the ...     12
#
# [46262 rows x 3 columns]

# %%
combined_validation = pd.concat([validation_mfc,validation_ph], axis=0, ignore_index=True)
combined_validation
# Out:
#        code_frames                                               text  label
# 0               13  Politically speaking, this has been true for s...     12
# 1                1                    BIG TOBACCO BLOWS SMOKE - AGAIN      0
# 2                4                     Gender Bias in Immigration Law      3
# 3                5  Jury Begins Deliberations In Wendy's Massacre ...      4
# 4               10                      GROUP EYEING PARTNER BENEFITS      9
# ...            ...                                                ...    ...
# 11561            7  DOJ eyes deportation of Japanese fugitives by ...      6
# 11562            1  The Philippines can withdraw from the Regional...      0
# 11563           15  President Ferdinand "Bongbong" Marcos Jr. expr...     14
# 11564            2  MANILA – At least 20,000 farmers in Aklan prov...      1
# 11565            6  The repeal of the Revised Penal Code provision...      5
#
# [11566 rows x 3 columns]

# %%
# combined_train.to_csv(f'{dir}/dataset/final/combined_train.csv', index=False)
# combined_validation.to_csv(f'{dir}/dataset/final/combined_validation.csv', index=False)

# %%
phi = pd.read_csv(f'{dir}dataset/final/ph_dataset.csv', usecols=['text', 'code_frames'])
phi['Source'] = "PH"
phi
# Out:
#                                                     text  code_frames Source
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...            4     PH
# 1      The number of Filipinos against changing the C...           12     PH
# 2      Jinggoy Estrada calls ICC probers 'white monke...           13     PH
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...           13     PH
# 4      The Department of Health (DOH) on Thursday mon...            9     PH
# ...                                                  ...          ...    ...
# 12288  PH diplomat tells China not to question PH-US ...           14     PH
# 12289  Philippine Ambassador to the United States Jos...           14     PH
# 12290  China enjoins Asian countries to uphold ‘strat...           14     PH
# 12291  China wants countries in Asia to “uphold strat...           14     PH
# 12292  Public told: ‘Remember, honor, emulate valor o...           11     PH
#
# [12293 rows x 3 columns]

# %%
mediafc = pd.read_csv(f'{dir}dataset/final/mfc.csv', usecols=['text', 'code_frames'])
mediafc['Source'] = "MFC"
mediafc
# Out:
#        code_frames                                               text Source
# 0               10  Immigrants without HOPE need help entering col...    MFC
# 1                5  But in the eyes of the law, he is an illegal i...    MFC
# 2               15            Reaction to Tancredo, Lamm as predicted    MFC
# 3               13  That, said the congressman, is what always hap...    MFC
# 4                1                                  $50,000 per entry    MFC
# ...            ...                                                ...    ...
# 45530           11                 Smoking is becoming a social taboo    MFC
# 45531            5   Nor does it aid lawyers seeking novel ways to...    MFC
# 45532           15                                   'Ashes to Ashes'    MFC
# 45533           15          SMOKE SCREEN IS SEEN BEHIND THE SMOKELESS    MFC
# 45534            1             CIGARETTE MAKERS AND THE PUBLIC HEALTH    MFC
#
# [45535 rows x 3 columns]

# %%
all_combined = pd.concat([phi,mediafc], axis=0, ignore_index=True)
all_combined
# Out:
#                                                     text  code_frames Source
# 0      Dumagat-Remontados opposed to Kaliwa Dam urge ...            4     PH
# 1      The number of Filipinos against changing the C...           12     PH
# 2      Jinggoy Estrada calls ICC probers 'white monke...           13     PH
# 3      President Ferdinand “Bongbong” Marcos Jr. has ...           13     PH
# 4      The Department of Health (DOH) on Thursday mon...            9     PH
# ...                                                  ...          ...    ...
# 57823                 Smoking is becoming a social taboo           11    MFC
# 57824   Nor does it aid lawyers seeking novel ways to...            5    MFC
# 57825                                   'Ashes to Ashes'           15    MFC
# 57826          SMOKE SCREEN IS SEEN BEHIND THE SMOKELESS           15    MFC
# 57827             CIGARETTE MAKERS AND THE PUBLIC HEALTH            1    MFC
#
# [57828 rows x 3 columns]

# %%
# all_combined.to_csv(f'{dir}dataset/final/final_combined.csv', index=False)
