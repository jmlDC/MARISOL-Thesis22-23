# %% [markdown]
# <a href="https://colab.research.google.com/github/jmlDC/MediaBias-Thesis22-23/blob/Modeling/Cleaner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mounting Gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

dir  = "/content/gdrive/MyDrive/THESIS-MS/Git-Thesis22-23/"
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import nltk
nltk.download('punkt')

from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 31.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=21b0c2a90a97e47fe53596102ae84a218269208f6646c66861f406477cd0b3b3
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %% [markdown]
# ### Function

# %%
# Stop words and empty lines
# (PNA photo by
# (Photo courtesy by ) not captured
import re

def make_annotateDF(df, isSunStar=False):
    workingDF = pd.DataFrame(columns=['Annotate','Text'])

    for index, row in df.iterrows():
        # print(df['Title'].iloc[index])
        if (row['Title'] == 'MB Daily News Summary'):
            pass
        else:
            new_row = pd.DataFrame({'Annotate':'', 'Text': df['Title'].iloc[index]}, index=[0])
            workingDF = pd.concat([workingDF.loc[:], new_row]).reset_index(drop=True)
            text = str(df['Text'].iloc[index])
            # print(text)
            if isSunStar:
                sentences = sent_tokenize(text)
            else:
                sentences = text.split('\n')
            for sentence in sentences:
                sentence = re.sub(r"http\S+", "", sentence)
                sentence = re.sub(r"@\S+", "", sentence)
                sentence = re.sub(r"\S+.com\S+", "", sentence)
                sentence = sentence.replace("– Rappler.com","")
                sentence = sentence.replace("(PNA)","")

                if (', GMA Integrated News' in sentence
                    or sentence ==''
                    or sentence =='– Rappler.com'
                    or 'SunStar Philippines)' in sentence
                    or 'File photo' in sentence
                    or 'Courtesy of ' in sentence
                    or len(sentence.split()) <3
                    or 'RELATED STORY' in sentence
                    or '(Photo: '  in sentence
                    or 'Rappler.com' in sentence
                    or '(Photo courtesy of' in sentence
                    ):
                    # print(sentence)
                    pass
                else:
                    new_row = pd.DataFrame({'Annotate':'', 'Text': sentence}, index=[0])
                    workingDF = pd.concat([workingDF.loc[:], new_row]).reset_index(drop=True)

    return workingDF

# %%
from langdetect import detect
import re

from langdetect import DetectorFactory
DetectorFactory.seed = 0

def get_headlineLead(df, isSunStar=False, isPNA=False):
    workingDF = pd.DataFrame(columns=['Text', 'Annotate'])

    for index, row in df.iterrows():
        # print(df['Title'].iloc[index])
        try:
            lang = detect(df['Title'].iloc[index])
        except:
            lang = ""

        if (lang == 'tl'):
            # print(df['Title'].iloc[index])
            pass
        if (row['Title'] == 'MB Daily News Summary'):
            pass
        else:
            new_row = pd.DataFrame({'Annotate':'', 'Text': df['Title'].iloc[index]}, index=[0])
            workingDF = pd.concat([workingDF.loc[:], new_row]).reset_index(drop=True)
            text = str(df['Text'].iloc[index])

            if isSunStar:
                text = re.sub(r'\.(?=[^ \W\d])', '. ', text)
                sentences = sent_tokenize(text)

            else:
                sentences = text.split('\n')

            if isPNA:
                for text in sentences:
                    if text.startswith('MANILA'):
                        sentence = text
                        sentence = sentence.strip()
                        break
            else:
                sentence = sentences[0].strip()



            sentence = re.sub(r"http\S+", "", sentence)
            sentence = re.sub(r"@\S+", "", sentence)
            sentence = re.sub(r"\S+.com\S+", "", sentence)
            sentence = sentence.replace("– Rappler.com","")
            sentence = sentence.replace("(PNA)","")

            if (', GMA Integrated News' in sentence
                    or sentence ==''
                    or sentence =='– Rappler.com'
                    or 'SunStar Philippines)' in sentence
                    or 'File photo' in sentence
                    or 'Courtesy of ' in sentence
                    or len(sentence.split()) <3
                    or 'RELATED STORY' in sentence
                    or '(Photo: '  in sentence
                    or 'Rappler.com' in sentence
                    or '(Photo courtesy of' in sentence
                    ):
                    # print(sentence)
                pass
            else:
                new_row = pd.DataFrame({'Annotate':'', 'Text': sentence}, index=[0])
                workingDF = pd.concat([workingDF.loc[:], new_row]).reset_index(drop=True)

    return workingDF

# %% [markdown]
# ## Main

# %% [markdown]
# ### GMA

# %%
gma = pd.read_csv(f'{dir}Official/GMA_2023-05-07NEWS.csv')
gma
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  DOH logs 1,920 new COVID-19 cases, highest dai...
# 1              1  DOH logs 9 new COVID-19 deaths; 1,878 fresh ca...
# 2              2  Bettor wins P55.3 million jackpot in Grand Lot...
# 3              3  Filipinos watch as King Charles III of Britain...
# 4              4        Marcos will not abolish NTF-ELCAC, says NSC
# ...          ...                                                ...
# 2218        2218  SC upholds House journal over videos, photos; ...
# 2219        2219  Philippines' justice chief says ICC drug war p...
# 2220        2220  De Lima drug cases may be resolved by March —l...
# 2221        2221  Philippines to appeal ICC’s resumption of drug...
# 2222        2222  Reported death toll from bad weather now at 40...
#
#                                           Author        Date  \
# 0                         By GMA Integrated News  2023-05-07
# 1                                            NaN  2023-05-07
# 2                         By GMA Integrated News  2023-05-07
# 3                         By GMA Integrated News  2023-05-06
# 4                         By GMA Integrated News  2023-05-06
# ...                                          ...         ...
# 2218  By JOAHNA LEI CASILAO, GMA Integrated News  2023-01-27
# 2219  By JOAHNA LEI CASILAO, GMA Integrated News  2023-01-27
# 2220  By JOAHNA LEI CASILAO, GMA Integrated News  2023-01-27
# 2221  By JOAHNA LEI CASILAO, GMA Integrated News  2023-01-27
# 2222                                         NaN  2023-01-27
#
#                                                    Text
# 0      The Philippines on Sunday registered 1,920 ne...
# 1      The Department of Health said Saturday that t...
# 2      A bettor won the jackpot prize of P55,394,255...
# 3      Filipinos monitored the coronation of the Uni...
# 4      President Ferdinand R. Marcos Jr. has no inte...
# ...                                                 ...
# 2218   The Supreme Court has upheld the constitution...
# 2219   Justice Secretary Jesus Crispin Remulla descr...
# 2220   The camp of detained former Senator Leila de ...
# 2221   The Philippine government intends to appeal t...
# 2222   There are now 40 reported fatalities due to i...
#
# [2223 rows x 5 columns]

# %%
gma_df = make_annotateDF(gma)
gma_df
# Out:
#       Annotate                                               Text
# 0               DOH logs 1,920 new COVID-19 cases, highest dai...
# 1                The Philippines on Sunday registered 1,920 ne...
# 2                According to GMA Integrated News Research, th...
# 3                It is the fourth straight day of more than 1,...
# 4                Data from the Department of Health's COVID-19...
# ...        ...                                                ...
# 27781            A total of 1,964,679 individuals or 481,012 f...
# 27782            Of the affected population, 88,134 individual...
# 27783            A total of 1,858 houses were reported damaged...
# 27784            Damage to agriculture worth PP885,165,517 and...
# 27785            A state of calamity was declared in 85 cities...
#
# [27786 rows x 2 columns]

# %%
gmaHL_df = get_headlineLead(gma)
gmaHL_df
# Out:
#                                                    Text Annotate
# 0     DOH logs 1,920 new COVID-19 cases, highest dai...
# 1     The Philippines on Sunday registered 1,920 new...
# 2     DOH logs 9 new COVID-19 deaths; 1,878 fresh ca...
# 3     The Department of Health said Saturday that th...
# 4     Bettor wins P55.3 million jackpot in Grand Lot...
# ...                                                 ...      ...
# 4406  The camp of detained former Senator Leila de L...
# 4407  Philippines to appeal ICC’s resumption of drug...
# 4408  The Philippine government intends to appeal th...
# 4409  Reported death toll from bad weather now at 40...
# 4410  There are now 40 reported fatalities due to in...
#
# [4411 rows x 2 columns]

# %% [markdown]
# ### PNA

# %%
pna = pd.read_csv(f'{dir}Official/PhilippineNewsAgency_2023-05-06NEWS.csv')
pna
# Out:
#       Unnamed: 0                                              Title  \
# 0              0      MIAA, Meralco begins NAIA T3 electrical audit
# 1              1  Pag-IBIG, Singaporean firm eye building ‘net-z...
# 2              2  DMW assures aid for OFWS from Sudan who wanted...
# 3              3  PNP chief fetes HPG's vital role in upholding ...
# 4              4  LTO chief: 'Fixers,' fake docs jeopardize publ...
# ...          ...                                                ...
# 2195        2195  PBBM's 'Pambansang Pabahay’ empowers LGUs to a...
# 2196        2196  1.2K cops to secure ASEAN education execs' mee...
# 2197        2197  PNP reaffirms support to Interpol efforts vs. ...
# 2198        2198  IP leaders call for unity to preserve IPRA, NC...
# 2199        2199  PH, US Navy fleets to tackle cooperation, exch...
#
#                                          Author              Date  \
# 0                                           NaN       May 5, 2023
# 1                                           NaN       May 5, 2023
# 2                               By Marita Moaje       May 5, 2023
# 3                  By Christopher Lloyd Caliwan       May 5, 2023
# 4                     By Raymond Carl Dela Cruz       May 5, 2023
# ...                                         ...               ...
# 2195                         By Zaldy De Layola  February 8, 2023
# 2196               By Christopher Lloyd Caliwan  February 8, 2023
# 2197               By Christopher Lloyd Caliwan  February 8, 2023
# 2198  By Perfecto Raymundo, Jr. and Che Palicte  February 8, 2023
# 2199                        By Priam Nepomuceno  February 8, 2023
#
#                                                    Text
# 0     File photo\nMANILA – The Manila International ...
# 1     MANILA – Marilene Acosta, the CEO of Pag-IBIG ...
# 2     HOME. A total of 74 repatriates from war-torn ...
# 3     PNP chief Gen. Benjamin Acorda Jr. (PNA photo ...
# 4     MANILA – The chief of the Land Transportation ...
# ...                                                 ...
# 2195  (File photo)\nMANILA – The Department of Human...
# 2196  (Photo courtesy of NCRPO)\nMANILA – More than ...
# 2197  Interpol Secretary General Jürgen Stock (left)...
# 2198  UNITY. Indigenous people leaders call for unit...
# 2199  (Photo courtesy of Philippine Fleet)\nMANILA –...
#
# [2200 rows x 5 columns]

# %%
# pna_df = make_annotateDF(pna)
# pna_df
# Out:
#       Annotate                                               Text
# 0                   MIAA, Meralco begins NAIA T3 electrical audit
# 1               MANILA – The Manila International Airport Auth...
# 2               MIAA officer-in-charge Bryan Co said the audit...
# 3               Co added that once the audit is concluded, the...
# 4               The MIAA will then determine the timeline as w...
# ...        ...                                                ...
# 28692           He added that Philippine  Rear Admiral Renato ...
# 28693           "The meeting will yield meaningful discussions...
# 28694           He added the staff-to-staff talks between the ...
# 28695           Badidles added that the activity is part of th...
# 28696           "Last October 11, 2022, a landmark Terms of Re...
#
# [28697 rows x 2 columns]

# %%
pnaHL_df = get_headlineLead(pna, isPNA=True)
pnaHL_df
# Out:
#                                                    Text Annotate
# 0         MIAA, Meralco begins NAIA T3 electrical audit
# 1     MANILA – The Manila International Airport Auth...
# 2     Pag-IBIG, Singaporean firm eye building ‘net-z...
# 3     MANILA – Marilene Acosta, the CEO of Pag-IBIG ...
# 4     DMW assures aid for OFWS from Sudan who wanted...
# ...                                                 ...      ...
# 4395  MANILA – More than 1,200 police officers have ...
# 4396  IP leaders call for unity to preserve IPRA, NC...
# 4397  MANILA – Leaders of the indigenous peoples (IP...
# 4398  PH, US Navy fleets to tackle cooperation, exch...
# 4399  MANILA – The Philippine Fleet and US 7th Fleet...
#
# [4400 rows x 2 columns]

# %% [markdown]
# ### Rappler

# %%
rappler = pd.read_csv(f'{dir}Official/Rappler_2023-05-07NEWS.csv')
rappler
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Marcos the party-going schoolboy returns to UK...
# 1              1  Ablan confirms resignation from DepEd, denies ...
# 2              2  WATCH: Paano naibenta sa labas ang DepEd lapto...
# 3              3  In unprecedented move, Filipino journalist har...
# 4              4  Marcos says Philippines bases could be ‘useful...
# ...          ...                                                ...
# 2196        2196   Fewer Filipinos skeptical of COVID-19 jabs – SWS
# 2197        2197  Duterte appoints Malacañang official, ex-Napol...
# 2198        2198  ‘Ironclad’ PH-South Korea alliance seen with s...
# 2199        2199  3 Cordillera provinces, Northern Samar placed ...
# 2200        2200     Comelec starts printing ballots for 2022 polls
#
#               Author        Date  \
# 0          Lian Buan  2023-05-05
# 1      Ryan Macasero  2023-05-05
# 2        Rappler.com  2023-05-05
# 3        Gaby Baizas  2023-05-05
# 4            Reuters  2023-05-05
# ...              ...         ...
# 2196  Sofia Tomacruz  2022-01-21
# 2197             NaN  2022-01-21
# 2198   Jairo Bolledo  2022-01-21
# 2199             NaN  2022-01-20
# 2200  Dwight de Leon  2022-01-20
#
#                                                    Text
# 0     LONDON, United Kingdom – In the late ’70s, Fer...
# 1     MANILA, Philippines – Former Department of Edu...
# 2     MANILA, Philippines – Naaalala ‘nyo ba ‘yung m...
# 3     MANILA, Philippines – Days after media workers...
# 4     WASHINGTON DC, USA – Philippines President Fer...
# ...                                                 ...
# 2196  MANILA, Philippines – As the coronavirus is po...
# 2197  MANILA, Philippines – President Rodrigo Dutert...
# 2198  MANILA, Philippines – The Philippines is looki...
# 2199  MANILA, Philippines – The alert level of three...
# 2200  The printing of official ballots for the 2022 ...
#
# [2201 rows x 5 columns]

# %%
rappler_df = make_annotateDF(rappler)
rappler_df
# Out:
#       Annotate                                               Text
# 0               Marcos the party-going schoolboy returns to UK...
# 1               LONDON, United Kingdom – In the late ’70s, Fer...
# 2               Marcos, his first lady Louise Araneta Marcos a...
# 3               “Sa palagay ko, dahil magkakilala kami, eh dap...
# 4                 Besides, said Locsin, “he left his heart here.”
# ...        ...                                                ...
# 33998           On January 22, Jimenez acknowledged that the T...
# 33999           “Because the ballots have not yet been printed...
# 34000           The printing of ballots was supposed to start ...
# 34001           Some 67.4 million ballots will be printed over...
# 34002            had guaranteed there was a contingency plan i...
#
# [34003 rows x 2 columns]

# %%
rapplerHL_df = get_headlineLead(rappler)
rapplerHL_df
# Out:
#                                                    Text Annotate
# 0     Marcos the party-going schoolboy returns to UK...
# 1     LONDON, United Kingdom – In the late ’70s, Fer...
# 2     Ablan confirms resignation from DepEd, denies ...
# 3     MANILA, Philippines – Former Department of Edu...
# 4     WATCH: Paano naibenta sa labas ang DepEd lapto...
# ...                                                 ...      ...
# 4394  MANILA, Philippines – The Philippines is looki...
# 4395  3 Cordillera provinces, Northern Samar placed ...
# 4396  MANILA, Philippines – The alert level of three...
# 4397     Comelec starts printing ballots for 2022 polls
# 4398  The printing of official ballots for the 2022 ...
#
# [4399 rows x 2 columns]

# %% [markdown]
# ### SunStar

# %%
sunstar = pd.read_csv(f'{dir}Official/SunStar_2023-05-07NEWS.csv')
sunstar
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Sandiganbayan affirms denial of motion seeking...
# 1              1  PH to reassess protocols with end of Covid glo...
# 2              2  DMW: Work experience top criterion for oversea...
# 3              3  Marcos accepts courtesy resignation of 2 senio...
# 4              4  DOH reiterates call for kids to get measles, p...
# ...          ...                                                ...
# 2261        2261    CSF indigents get cash aid, food packs from Guv
# 2262        2262   AC execs help Bale Pusu ward reunite with family
# 2263        2263                Cops seize P14-M 'shabu' in Bulacan
# 2264        2264       Crissot's 156 birth anniversary commemorated
# 2265        2265    CSF council inquiry on power rate hike launched
#
#                           Author              Date  \
# 0     Third Anne Peralta-Malonzo      May 07, 2023
# 1                            NaN      May 06, 2023
# 2                            NaN      May 06, 2023
# 3     Third Anne Peralta-Malonzo      May 05, 2023
# 4                            NaN      May 05, 2023
# ...                          ...               ...
# 2261            Ian Ocampo Flora  January 30, 2023
# 2262        Charlene A. Cayabyab  January 28, 2023
# 2263      Princess Clea Arcellaz  January 28, 2023
# 2264            Ian Ocampo Flora  January 28, 2023
# 2265      Princess Clea Arcellaz  January 28, 2023
#
#                                                    Text
# 0     THE Sandiganbayan has affirmed the decision of...
# 1     WITH the end of the global emergency status fo...
# 2     THE Department of Migrant Workers (DMW) on Sat...
# 3     PRESIDENT Ferdinand “Bongbong” Marcos has conf...
# 4     FIVE days after starting its mass immunization...
# ...                                                 ...
# 2261  CITY OF SAN FERNANDO The provincial government...
# 2262  ANGELES CITY The city government here has faci...
# 2263  CITY OF SAN FERNANDO More than two kilos of su...
# 2264  BACOLOR The heirs of Juan Crisostomo Soto (Cri...
# 2265  CITY OF SAN FERNANDO The Sangguniang Panlungso...
#
# [2266 rows x 5 columns]

# %%
sunstar_df = make_annotateDF(sunstar, isSunStar=True)
sunstar_df
# Out:
#       Annotate                                               Text
# 0               Sandiganbayan affirms denial of motion seeking...
# 1               THE Sandiganbayan has affirmed the decision of...
# 2               A careful reading of the defendants’ motion sh...
# 3               In view of the foregoing, the defendants faile...
# 4               The Court thus maintains its earlier pronounce...
# ...        ...                                                ...
# 17797           The said session was attended by representativ...
# 17798           During the inquiry, SFELAPCO representatives e...
# 17799           It was also disclosed that the expiration of S...
# 17800           Macalino assailed SFELAPCO’s alleged lack of c...
# 17801           The power provider executives responded by say...
#
# [17802 rows x 2 columns]

# %%
sunstarHL_df = get_headlineLead(sunstar, isSunStar=True)
sunstarHL_df
# Out:
#                                                    Text Annotate
# 0     Sandiganbayan affirms denial of motion seeking...
# 1     THE Sandiganbayan has affirmed the decision of...
# 2     PH to reassess protocols with end of Covid glo...
# 3     WITH the end of the global emergency status fo...
# 4     DMW: Work experience top criterion for oversea...
# ...                                                 ...      ...
# 4516  CITY OF SAN FERNANDO More than two kilos of su...
# 4517       Crissot's 156 birth anniversary commemorated
# 4518  BACOLOR The heirs of Juan Crisostomo Soto (Cri...
# 4519    CSF council inquiry on power rate hike launched
# 4520  CITY OF SAN FERNANDO The Sangguniang Panlungso...
#
# [4521 rows x 2 columns]

# %% [markdown]
# ### Manila Bulletin

# %%
mb = pd.read_csv(f'{dir}Official/manilaBulletin_2023-05-05_NEWS.csv')
mb
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  'Thank you gov': Cong Roman mourns passing of ...
# 1              1  P5-M reward offered to find missing Chinese pa...
# 2              2  Hontiveros: Nuclear energy a terrible, false s...
# 3              3  You go girl! Pro-sports solon hails Kaila Napo...
# 4              4  Expedite release of Excellence in Teacher Educ...
# ...          ...                                                ...
# 1999        1999  Diokno, Australian envoy share notes on deepen...
# 2000        2000  Australian gov't drums up interest in PH airpo...
# 2001        2001  Proposed EBET law passed on 3rd reading; here'...
# 2002        2002  Immediate expansion of gov’t subsidies to kind...
# 2003        2003  P​H, China vow UNCLOS​ compliance, seek Indo-P...
#
#                         Author           Date  \
# 0             Ellson Quismorio   May 5, 2023
# 1            Martin Sadongdong   May 5, 2023
# 2             Hannah Torregoza   May 5, 2023
# 3             Ellson Quismorio   May 5, 2023
# 4     Merlina Hernando-Malipot   May 5, 2023
# ...                        ...            ...
# 1999           Raymund Antonio  Mar 25, 2023
# 2000           Raymund Antonio  Mar 25, 2023
# 2001          Ellson Quismorio  Mar 25, 2023
# 2002  Merlina Hernando-Malipot  Mar 25, 2023
# 2003           Joseph Pedrajas  Mar 25, 2023
#
#                                                    Text
# 0     Bataan 1st district Rep. Geraldine Roman paid ...
# 1     A P5-million reward was offered to anyone who ...
# 2      \nSenator Risa Hontiveros on Friday, May 5 qu...
# 3     The first one is always special.\nPuwersa ng B...
# 4     To further strengthen teacher education in the...
# ...                                                 ...
# 1999  Finance Secretary Benjamin Diokno met with Aus...
# 2000  The Australian government is looking to “drum ...
# 2001  The lower chamber recently gave its final appr...
# 2002  A network of advocates called for the immediat...
# 2003  The Philippines and China have agreed to adher...
#
# [2004 rows x 5 columns]

# %%
mb_df = make_annotateDF(mb)
mb_df
# Out:
#       Annotate                                               Text
# 0               'Thank you gov': Cong Roman mourns passing of ...
# 1               Bataan 1st district Rep. Geraldine Roman paid ...
# 2               "It is with a heavy heart that I offer my sinc...
# 3               "His  to enriching the lives of others through...
# 4               "Thank you Governor Padilla for your service. ...
# ...        ...                                                ...
# 23804           "The Philippines and China also discussed new ...
# 23805           On Thursday, Lazaro started chairing with Chin...
# 23806           The conduct of the BCM, a confidence-building ...
# 23807           In an earlier pronouncement, Lazaro asserted t...
# 23808           This came as China is accused of conducting gr...
#
# [23809 rows x 2 columns]

# %%
mbHL_df = get_headlineLead(mb)
mbHL_df
# Out:
#                                                    Text Annotate
# 0     'Thank you gov': Cong Roman mourns passing of ...
# 1     Bataan 1st district Rep. Geraldine Roman paid ...
# 2     P5-M reward offered to find missing Chinese pa...
# 3     A P5-million reward was offered to anyone who ...
# 4     Hontiveros: Nuclear energy a terrible, false s...
# ...                                                 ...      ...
# 3868  The lower chamber recently gave its final appr...
# 3869  Immediate expansion of gov’t subsidies to kind...
# 3870  A network of advocates called for the immediat...
# 3871  P​H, China vow UNCLOS​ compliance, seek Indo-P...
# 3872  The Philippines and China have agreed to adher...
#
# [3873 rows x 2 columns]

# %%
mb_df.iloc[19]
# Out:
# Annotate
# Text        Hontiveros reiterated her belief that nuclear ...
# Name: 19, dtype: object

# %% [markdown]
# ## END

# %%
ALL_df = pd.concat([gma_df, pna_df, rappler_df, sunstar_df, mb_df])
ALL_df

# ALL_df.to_csv(f'{dir}/Official/curated_Dataset.csv', index=False)

# %%
ALL_HL_df = pd.concat([gmaHL_df, pnaHL_df, rapplerHL_df, sunstarHL_df, mbHL_df])
ALL_HL_df

ALL_HL_df.to_csv(f'{dir}/Official/curated_Dataset_headlines_lead.csv', index=False)

# %%
ALL_HL_df
# Out:
#                                                    Text Annotate
# 0     DOH logs 1,920 new COVID-19 cases, highest dai...
# 1     The Philippines on Sunday registered 1,920 new...
# 2     DOH logs 9 new COVID-19 deaths; 1,878 fresh ca...
# 3     The Department of Health said Saturday that th...
# 4     Bettor wins P55.3 million jackpot in Grand Lot...
# ...                                                 ...      ...
# 3868  The lower chamber recently gave its final appr...
# 3869  Immediate expansion of gov’t subsidies to kind...
# 3870  A network of advocates called for the immediat...
# 3871  P​H, China vow UNCLOS​ compliance, seek Indo-P...
# 3872  The Philippines and China have agreed to adher...
#
# [21604 rows x 2 columns]

# %%
ALL_df
# Out:
#       Annotate                                               Text
# 0               DOH logs 1,920 new COVID-19 cases, highest dai...
# 1                The Philippines on Sunday registered 1,920 ne...
# 2                According to GMA Integrated News Research, th...
# 3                It is the fourth straight day of more than 1,...
# 4                Data from the Department of Health's COVID-19...
# ...        ...                                                ...
# 23804           "The Philippines and China also discussed new ...
# 23805           On Thursday, Lazaro started chairing with Chin...
# 23806           The conduct of the BCM, a confidence-building ...
# 23807           In an earlier pronouncement, Lazaro asserted t...
# 23808           This came as China is accused of conducting gr...
#
# [132097 rows x 2 columns]
# Warning: total number of rows (132097) exceeds max_rows (20000). Limiting to first (20000) rows.
